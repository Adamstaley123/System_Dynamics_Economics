# %% [markdown]
# # Data Processing File

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# List of CSV files and their corresponding column names
csv_files = {
    'Consumer_sentiment.csv': 'UMCSENT',
    'CPI_Urban_consumers.csv': 'CPILFESL',
    'Implicit_price_deflator.csv': 'A191RI1Q225SBEA',
    'Industrial_production.csv': 'INDPRO',
    'Labor_Productivity.csv': 'PRS85006091',
    'PPI.csv': 'PPIACO',
    'Real_disposable_Personal_income.csv': 'DSPIC96',
    'Real_GDP.csv': 'GDPC1',
    'Unemployment_rate.csv': 'UNRATE'
}

# Function to load and process each CSV file
def load_csv(file_name, column_name):
    df = pd.read_csv(file_name)
    df['DATE'] = pd.to_datetime(df['DATE'])
    df = df.set_index('DATE')
    df = df[[column_name]]
    df.columns = [file_name.split('.')[0]]
    
    # Convert to numeric, coercing errors to NaN
    df = df.apply(pd.to_numeric, errors='coerce')
    
    return df

# Load all CSV files
dataframes = [load_csv(file, column) for file, column in csv_files.items()]

# Merge all dataframes
merged_df = pd.concat(dataframes, axis=1)

# Filter data from 1979 onwards
merged_df = merged_df.loc['1979-01-01':]

# Print info about the merged dataframe
print(merged_df.info())
print("\nFirst few rows of the merged dataframe:")
print(merged_df.head())
print("\nLast few rows of the merged dataframe:")
print(merged_df.tail())

# Check for missing values
print("\nMissing values in each column:")
print(merged_df.isnull().sum())

# Calculate percentage of missing values
missing_percentage = (merged_df.isnull().sum() / len(merged_df)) * 100
print("\nPercentage of missing values in each column:")
print(missing_percentage)

# Visualize each metric
plt.figure(figsize=(20, 15))
for i, column in enumerate(merged_df.columns, 1):
    plt.subplot(3, 3, i)
    plt.plot(merged_df.index, merged_df[column])
    plt.title(f"{column}\nMissing: {missing_percentage[column]:.2f}%")
    plt.xticks(rotation=45)
    plt.tight_layout()
plt.savefig('economic_metrics_visualization.png')
plt.close()

# Create correlation matrix
correlation_matrix = merged_df.corr()

# Visualize correlation matrix
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1, center=0)
plt.title('Correlation Matrix of Economic Metrics')
plt.tight_layout()
plt.savefig('correlation_matrix.png')
plt.close()

print("\nCorrelation Matrix:")
print(correlation_matrix)

# Basic statistics
print("\nBasic statistics of the data:")
print(merged_df.describe())

# Print the date range for each column
print("\nDate range for each column:")
for column in merged_df.columns:
    start_date = merged_df[column].first_valid_index()
    end_date = merged_df[column].last_valid_index()
    print(f"{column}: {start_date} to {end_date}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 547 entries, 1979-01-01 to 2024-07-01
# Freq: MS
# Data columns (total 9 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Consumer_sentiment               546 non-null    float64
#  1   CPI_Urban_consumers              547 non-null    float64
#  2   Implicit_price_deflator          182 non-null    float64
#  3   Industrial_production            546 non-null    float64
#  4   Labor_Productivity               182 non-null    float64
#  5   PPI                              547 non-null    float64
#  6   Real_disposable_Personal_income  546 non-null    float64
#  7   Real_GDP                         182 non-null    float64
#  8   Unemployment_rate                547 non-null    float64
# dtypes: float64(9)
# memory usage: 42.7 KB
# None
#
# First few rows of the merged dataframe:
#             Consumer_sentiment  CPI_Urban_consumers  Implicit_price_deflator  \
# DATE
# 1979-01-01                72.1                 68.5                      7.5
# 1979-02-01                73.9                 69.2                      NaN
# 1979-03-01                68.4                 69.8                      NaN
# 1979-04-01                66.0                 70.3                     10.2
# 1979-05-01                68.1                 70.8                      NaN
#
#             Industrial_production  Labor_Productivity   PPI  \
# DATE
# 1979-01-01                51.5250                 1.8  73.8
# 1979-02-01                51.7780                 NaN  74.9
# 1979-03-01                51.9382                 NaN  75.8
# 1979-04-01                51.3251                -0.4  76.9
# 1979-05-01                51.7782                 NaN  77.5
#
#             Real_disposable_Personal_income  Real_GDP  Unemployment_rate
# DATE
# 1979-01-01                           5164.0  7238.727                5.9
# 1979-02-01                           5184.7       NaN                5.9
# 1979-03-01                           5198.5       NaN                5.8
# 1979-04-01                           5156.1  7246.454                5.8
# 1979-05-01                           5132.2       NaN                5.6
#
# Last few rows of the merged dataframe:
#             Consumer_sentiment  CPI_Urban_consumers  Implicit_price_deflator  \
# DATE
# 2024-03-01                79.4              316.698                      NaN
# 2024-04-01                77.2              317.622                      2.3
# 2024-05-01                69.1              318.140                      NaN
# 2024-06-01                68.2              318.346                      NaN
# 2024-07-01                 NaN              318.872                      NaN
#
#             Industrial_production  Labor_Productivity      PPI  \
# DATE
# 2024-03-01               102.4062                 NaN  255.095
# 2024-04-01               102.4329                 2.7  256.984
# 2024-05-01               103.3282                 NaN  255.268
# 2024-06-01               103.9941                 NaN  255.779
# 2024-07-01                    NaN                 NaN  257.723
#
#             Real_disposable_Personal_income   Real_GDP  Unemployment_rate
# DATE
# 2024-03-01                          16924.3        NaN                3.8
# 2024-04-01                          16910.4  22918.739                3.9
# 2024-05-01                          16967.2        NaN                4.0
# 2024-06-01                          16984.4        NaN                4.1
# 2024-07-01                              NaN        NaN                4.3
#
# Missing values in each column:
# Consumer_sentiment                   1
# CPI_Urban_consumers                  0
# Implicit_price_deflator            365
# Industrial_production                1
# Labor_Productivity                 365
# PPI                                  0
# Real_disposable_Personal_income      1
# Real_GDP                           365
# Unemployment_rate                    0
# dtype: int64
#
# Percentage of missing values in each column:
# Consumer_sentiment                  0.182815
# CPI_Urban_consumers                 0.000000
# Implicit_price_deflator            66.727605
# Industrial_production               0.182815
# Labor_Productivity                 66.727605
# PPI                                 0.000000
# Real_disposable_Personal_income     0.182815
# Real_GDP                           66.727605
# Unemployment_rate                   0.000000
# dtype: float64
#
# Correlation Matrix:
#                                  Consumer_sentiment  CPI_Urban_consumers  \
# Consumer_sentiment                         1.000000            -0.093558
# CPI_Urban_consumers                       -0.093558             1.000000
# Implicit_price_deflator                   -0.364618            -0.401064
# Industrial_production                      0.047748             0.930858
# Labor_Productivity                         0.305881             0.035858
# PPI                                       -0.270755             0.959294
# Real_disposable_Personal_income           -0.111896             0.985920
# Real_GDP                                  -0.075787             0.991981
# Unemployment_rate                         -0.395504            -0.370520
#
#                                  Implicit_price_deflator  \
# Consumer_sentiment                             -0.364618
# CPI_Urban_consumers                            -0.401064
# Implicit_price_deflator                         1.000000
# Industrial_production                          -0.435616
# Labor_Productivity                             -0.369390
# PPI                                            -0.255569
# Real_disposable_Personal_income                -0.334857
# Real_GDP                                       -0.351307
# Unemployment_rate                               0.023986
#
#                                  Industrial_production  Labor_Productivity  \
# Consumer_sentiment                            0.047748            0.305881
# CPI_Urban_consumers                           0.930858            0.035858
# Implicit_price_deflator                      -0.435616           -0.369390
# Industrial_production                         1.000000            0.062822
# Labor_Productivity                            0.062822            1.000000
# PPI                                           0.859561           -0.122059
# Real_disposable_Personal_income               0.920483            0.050945
# Real_GDP                                      0.947412            0.022109
# Unemployment_rate                            -0.452949            0.167178
#
#                                       PPI  Real_disposable_Personal_income  \
# Consumer_sentiment              -0.270755                        -0.111896
# CPI_Urban_consumers              0.959294                         0.985920
# Implicit_price_deflator         -0.255569                        -0.334857
# Industrial_production            0.859561                         0.920483
# Labor_Productivity              -0.122059                         0.050945
# PPI                              1.000000                         0.950855
# Real_disposable_Personal_income  0.950855                         1.000000
# Real_GDP                         0.955356                         0.992363
# Unemployment_rate               -0.277662                        -0.331503
#
#                                  Real_GDP  Unemployment_rate
# Consumer_sentiment              -0.075787          -0.395504
# CPI_Urban_consumers              0.991981          -0.370520
# Implicit_price_deflator         -0.351307           0.023986
# Industrial_production            0.947412          -0.452949
# Labor_Productivity               0.022109           0.167178
# PPI                              0.955356          -0.277662
# Real_disposable_Personal_income  0.992363          -0.331503
# Real_GDP                         1.000000          -0.361243
# Unemployment_rate               -0.361243           1.000000
#
# Basic statistics of the data:
#        Consumer_sentiment  CPI_Urban_consumers  Implicit_price_deflator  \
# count          546.000000           547.000000               182.000000
# mean            84.980952           185.574307                 2.906593
# std             13.336066            62.096155                 2.152003
# min             50.000000            68.500000                -1.600000
# 25%             74.125000           134.750000                 1.700000
# 50%             89.000000           187.400000                 2.400000
# 75%             94.700000           232.681500                 3.275000
# max            112.000000           318.872000                11.000000
#
#        Industrial_production  Labor_Productivity         PPI  \
# count             546.000000          182.000000  547.000000
# mean               81.301382            1.815934  151.699351
# std                19.228243            1.701387   47.377697
# min                46.871300           -2.400000   73.800000
# 25%                61.722300            0.725000  114.550000
# 50%                89.502650            1.700000  133.300000
# 75%                98.885325            2.700000  193.050000
# max               104.103800            6.800000  280.251000
#
#        Real_disposable_Personal_income      Real_GDP  Unemployment_rate
# count                       546.000000    182.000000         547.000000
# mean                      10411.342125  14151.784868           6.073126
# std                        3618.736731   4636.795334           1.791287
# min                        5118.900000   7181.743000           3.400000
# 25%                        7205.800000  10006.405500           4.700000
# 50%                       10334.800000  14262.634000           5.700000
# 75%                       13014.275000  17619.263000           7.200000
# max                       20422.600000  22918.739000          14.800000
#
# Date range for each column:
# Consumer_sentiment: 1979-01-01 00:00:00 to 2024-06-01 00:00:00
# CPI_Urban_consumers: 1979-01-01 00:00:00 to 2024-07-01 00:00:00
# Implicit_price_deflator: 1979-01-01 00:00:00 to 2024-04-01 00:00:00
# Industrial_production: 1979-01-01 00:00:00 to 2024-06-01 00:00:00
# Labor_Productivity: 1979-01-01 00:00:00 to 2024-04-01 00:00:00
# PPI: 1979-01-01 00:00:00 to 2024-07-01 00:00:00
# Real_disposable_Personal_income: 1979-01-01 00:00:00 to 2024-06-01 00:00:00
# Real_GDP: 1979-01-01 00:00:00 to 2024-04-01 00:00:00
# Unemployment_rate: 1979-01-01 00:00:00 to 2024-07-01 00:00:00

# %%
merged_df
# Out:
#             Consumer_sentiment  CPI_Urban_consumers  Implicit_price_deflator  \
# DATE
# 1979-01-01                72.1               68.500                      7.5
# 1979-02-01                73.9               69.200                      NaN
# 1979-03-01                68.4               69.800                      NaN
# 1979-04-01                66.0               70.300                     10.2
# 1979-05-01                68.1               70.800                      NaN
# ...                        ...                  ...                      ...
# 2024-03-01                79.4              316.698                      NaN
# 2024-04-01                77.2              317.622                      2.3
# 2024-05-01                69.1              318.140                      NaN
# 2024-06-01                68.2              318.346                      NaN
# 2024-07-01                 NaN              318.872                      NaN
#
#             Industrial_production  Labor_Productivity      PPI  \
# DATE
# 1979-01-01                51.5250                 1.8   73.800
# 1979-02-01                51.7780                 NaN   74.900
# 1979-03-01                51.9382                 NaN   75.800
# 1979-04-01                51.3251                -0.4   76.900
# 1979-05-01                51.7782                 NaN   77.500
# ...                           ...                 ...      ...
# 2024-03-01               102.4062                 NaN  255.095
# 2024-04-01               102.4329                 2.7  256.984
# 2024-05-01               103.3282                 NaN  255.268
# 2024-06-01               103.9941                 NaN  255.779
# 2024-07-01                    NaN                 NaN  257.723
#
#             Real_disposable_Personal_income   Real_GDP  Unemployment_rate
# DATE
# 1979-01-01                           5164.0   7238.727                5.9
# 1979-02-01                           5184.7        NaN                5.9
# 1979-03-01                           5198.5        NaN                5.8
# 1979-04-01                           5156.1   7246.454                5.8
# 1979-05-01                           5132.2        NaN                5.6
# ...                                     ...        ...                ...
# 2024-03-01                          16924.3        NaN                3.8
# 2024-04-01                          16910.4  22918.739                3.9
# 2024-05-01                          16967.2        NaN                4.0
# 2024-06-01                          16984.4        NaN                4.1
# 2024-07-01                              NaN        NaN                4.3
#
# [547 rows x 9 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import interpolate

# ... (keep the csv_files dictionary and load_csv function as before)

# Load all CSV files
dataframes = [load_csv(file, column) for file, column in csv_files.items()]

# Merge all dataframes
merged_df = pd.concat(dataframes, axis=1)

# Filter data from 1979 onwards
merged_df = merged_df.loc['1979-01-01':]

# Approach 1: Convert to quarterly frequency using average
merged_df_quarterly_avg = merged_df.resample('Q').mean()

# Approach 2: Interpolate quarterly data to monthly
def interpolate_quarterly(series):
    if series.isnull().sum() > 0:  # Only interpolate if there are NaN values
        valid = series.notnull()
        indices = np.arange(len(series))
        interp_func = interpolate.interp1d(indices[valid], series[valid], kind='cubic', fill_value='extrapolate')
        return pd.Series(interp_func(indices), index=series.index)
    return series

merged_df_interpolated = merged_df.apply(interpolate_quarterly)

# Function to visualize and analyze data
def analyze_data(df, suffix):
    print(f"\nAnalysis for {suffix} data:")
    print(df.info())
    print("\nFirst few rows:")
    print(df.head())
    print("\nLast few rows:")
    print(df.tail())

    # Check for missing values
    missing = df.isnull().sum()
    missing_percentage = (missing / len(df)) * 100
    print("\nMissing values in each column:")
    print(missing)
    print("\nPercentage of missing values in each column:")
    print(missing_percentage)

    # Visualize each metric
    plt.figure(figsize=(20, 15))
    for i, column in enumerate(df.columns, 1):
        plt.subplot(3, 3, i)
        plt.plot(df.index, df[column])
        plt.title(f"{column}\nMissing: {missing_percentage[column]:.2f}%")
        plt.xticks(rotation=45)
    plt.tight_layout()
    plt.savefig(f'economic_metrics_visualization_{suffix}.png')
    plt.close()

    # Create correlation matrix
    correlation_matrix = df.corr()
    plt.figure(figsize=(12, 10))
    sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1, center=0)
    plt.title(f'Correlation Matrix of Economic Metrics ({suffix})')
    plt.tight_layout()
    plt.savefig(f'correlation_matrix_{suffix}.png')
    plt.close()

    print("\nCorrelation Matrix:")
    print(correlation_matrix)

    print("\nBasic statistics of the data:")
    print(df.describe())

    print("\nDate range for each column:")
    for column in df.columns:
        start_date = df[column].first_valid_index()
        end_date = df[column].last_valid_index()
        print(f"{column}: {start_date} to {end_date}")

# Analyze both approaches
analyze_data(merged_df_quarterly_avg, "quarterly_avg")
analyze_data(merged_df_interpolated, "interpolated")
# Out:
# Analysis for quarterly_avg data:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 183 entries, 1979-03-31 to 2024-09-30
# Freq: Q-DEC
# Data columns (total 9 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Consumer_sentiment               182 non-null    float64
#  1   CPI_Urban_consumers              183 non-null    float64
#  2   Implicit_price_deflator          182 non-null    float64
#  3   Industrial_production            182 non-null    float64
#  4   Labor_Productivity               182 non-null    float64
#  5   PPI                              183 non-null    float64
#  6   Real_disposable_Personal_income  182 non-null    float64
#  7   Real_GDP                         182 non-null    float64
#  8   Unemployment_rate                183 non-null    float64
# dtypes: float64(9)
# memory usage: 14.3 KB
# None
#
# First few rows:
#             Consumer_sentiment  CPI_Urban_consumers  Implicit_price_deflator  \
# DATE
# 1979-03-31           71.466667            69.166667                      7.5
# 1979-06-30           66.633333            70.800000                     10.2
# 1979-09-30           63.866667            72.633333                      9.0
# 1979-12-31           62.133333            74.833333                      7.6
# 1980-03-31           63.466667            77.600000                      8.7
#
#             Industrial_production  Labor_Productivity        PPI  \
# DATE
# 1979-03-31              51.747067                 1.8  74.833333
# 1979-06-30              51.629933                -0.4  77.466667
# 1979-09-30              51.477000                -0.6  79.900000
# 1979-12-31              51.673667                -1.3  82.700000
# 1980-03-31              51.884233                 0.0  86.533333
#
#             Real_disposable_Personal_income  Real_GDP  Unemployment_rate
# DATE
# 1979-03-31                      5182.400000  7238.727           5.866667
# 1979-06-30                      5135.733333  7246.454           5.700000
# 1979-09-30                      5159.733333  7300.281           5.866667
# 1979-12-31                      5170.000000  7318.535           5.966667
# 1980-03-31                      5189.700000  7341.557           6.300000
#
# Last few rows:
#             Consumer_sentiment  CPI_Urban_consumers  Implicit_price_deflator  \
# DATE
# 2023-09-30           69.566667           309.748333                      3.3
# 2023-12-31           64.933333           312.316000                      1.7
# 2024-03-31           78.433333           315.567000                      3.1
# 2024-06-30           71.500000           318.036000                      2.3
# 2024-09-30                 NaN           318.872000                      NaN
#
#             Industrial_production  Labor_Productivity         PPI  \
# DATE
# 2023-09-30             103.158467                 2.4  256.816333
# 2023-12-31             102.698600                 2.7  252.638000
# 2024-03-31             102.164567                 2.9  253.775667
# 2024-06-30             103.251733                 2.7  256.010333
# 2024-09-30                    NaN                 NaN  257.723000
#
#             Real_disposable_Personal_income   Real_GDP  Unemployment_rate
# DATE
# 2023-09-30                     16819.633333  22490.692           3.700000
# 2023-12-31                     16856.233333  22679.255           3.733333
# 2024-03-31                     16911.966667  22758.752           3.800000
# 2024-06-30                     16954.000000  22918.739           4.000000
# 2024-09-30                              NaN        NaN           4.300000
#
# Missing values in each column:
# Consumer_sentiment                 1
# CPI_Urban_consumers                0
# Implicit_price_deflator            1
# Industrial_production              1
# Labor_Productivity                 1
# PPI                                0
# Real_disposable_Personal_income    1
# Real_GDP                           1
# Unemployment_rate                  0
# dtype: int64
#
# Percentage of missing values in each column:
# Consumer_sentiment                 0.546448
# CPI_Urban_consumers                0.000000
# Implicit_price_deflator            0.546448
# Industrial_production              0.546448
# Labor_Productivity                 0.546448
# PPI                                0.000000
# Real_disposable_Personal_income    0.546448
# Real_GDP                           0.546448
# Unemployment_rate                  0.000000
# dtype: float64
#
# Correlation Matrix:
#                                  Consumer_sentiment  CPI_Urban_consumers  \
# Consumer_sentiment                         1.000000            -0.095465
# CPI_Urban_consumers                       -0.095465             1.000000
# Implicit_price_deflator                   -0.400870            -0.398204
# Industrial_production                      0.048486             0.931153
# Labor_Productivity                         0.338701             0.034253
# PPI                                       -0.275409             0.960362
# Real_disposable_Personal_income           -0.115218             0.986584
# Real_GDP                                  -0.090908             0.992023
# Unemployment_rate                         -0.403654            -0.376328
#
#                                  Implicit_price_deflator  \
# Consumer_sentiment                             -0.400870
# CPI_Urban_consumers                            -0.398204
# Implicit_price_deflator                         1.000000
# Industrial_production                          -0.438028
# Labor_Productivity                             -0.369390
# PPI                                            -0.245503
# Real_disposable_Personal_income                -0.337633
# Real_GDP                                       -0.351307
# Unemployment_rate                               0.033459
#
#                                  Industrial_production  Labor_Productivity  \
# Consumer_sentiment                            0.048486            0.338701
# CPI_Urban_consumers                           0.931153            0.034253
# Implicit_price_deflator                      -0.438028           -0.369390
# Industrial_production                         1.000000            0.068333
# Labor_Productivity                            0.068333            1.000000
# PPI                                           0.859979           -0.118901
# Real_disposable_Personal_income               0.921300            0.048265
# Real_GDP                                      0.947686            0.022109
# Unemployment_rate                            -0.454041            0.145405
#
#                                       PPI  Real_disposable_Personal_income  \
# Consumer_sentiment              -0.275409                        -0.115218
# CPI_Urban_consumers              0.960362                         0.986584
# Implicit_price_deflator         -0.245503                        -0.337633
# Industrial_production            0.859979                         0.921300
# Labor_Productivity              -0.118901                         0.048265
# PPI                              1.000000                         0.951888
# Real_disposable_Personal_income  0.951888                         1.000000
# Real_GDP                         0.955945                         0.993746
# Unemployment_rate               -0.283578                        -0.334105
#
#                                  Real_GDP  Unemployment_rate
# Consumer_sentiment              -0.090908          -0.403654
# CPI_Urban_consumers              0.992023          -0.376328
# Implicit_price_deflator         -0.351307           0.033459
# Industrial_production            0.947686          -0.454041
# Labor_Productivity               0.022109           0.145405
# PPI                              0.955945          -0.283578
# Real_disposable_Personal_income  0.993746          -0.334105
# Real_GDP                         1.000000          -0.390757
# Unemployment_rate               -0.390757           1.000000
#
# Basic statistics of the data:
#        Consumer_sentiment  CPI_Urban_consumers  Implicit_price_deflator  \
# count          182.000000           183.000000               182.000000
# mean            84.980952           186.059909                 2.906593
# std             13.080161            62.614627                 2.152003
# min             54.366667            69.166667                -1.600000
# 25%             74.775000           135.500000                 1.700000
# 50%             89.533333           187.966667                 2.400000
# 75%             94.200000           232.795000                 3.275000
# max            110.133333           318.872000                11.000000
#
#        Industrial_production  Labor_Productivity         PPI  \
# count             182.000000          182.000000  183.000000
# mean               81.301382            1.815934  152.085594
# std                19.257343            1.701387   47.788383
# min                47.145533           -2.400000   74.833333
# 25%                61.849650            0.725000  115.200000
# 50%                89.428467            1.700000  133.366667
# 75%                98.799167            2.700000  193.583333
# max               103.995800            6.800000  272.937333
#
#        Real_disposable_Personal_income      Real_GDP  Unemployment_rate
# count                       182.000000    182.000000         183.000000
# mean                      10411.342125  14151.784868           6.066667
# std                        3622.960796   4636.795334           1.785305
# min                        5135.733333   7181.743000           3.500000
# 25%                        7203.500000  10006.405500           4.700000
# 50%                       10368.816667  14262.634000           5.700000
# 75%                       13003.008333  17619.263000           7.216667
# max                       18378.266667  22918.739000          13.000000
#
# Date range for each column:
# Consumer_sentiment: 1979-03-31 00:00:00 to 2024-06-30 00:00:00
# CPI_Urban_consumers: 1979-03-31 00:00:00 to 2024-09-30 00:00:00
# Implicit_price_deflator: 1979-03-31 00:00:00 to 2024-06-30 00:00:00
# Industrial_production: 1979-03-31 00:00:00 to 2024-06-30 00:00:00
# Labor_Productivity: 1979-03-31 00:00:00 to 2024-06-30 00:00:00
# PPI: 1979-03-31 00:00:00 to 2024-09-30 00:00:00
# Real_disposable_Personal_income: 1979-03-31 00:00:00 to 2024-06-30 00:00:00
# Real_GDP: 1979-03-31 00:00:00 to 2024-06-30 00:00:00
# Unemployment_rate: 1979-03-31 00:00:00 to 2024-09-30 00:00:00
#
# Analysis for interpolated data:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 547 entries, 1979-01-01 to 2024-07-01
# Freq: MS
# Data columns (total 9 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Consumer_sentiment               547 non-null    float64
#  1   CPI_Urban_consumers              547 non-null    float64
#  2   Implicit_price_deflator          547 non-null    float64
#  3   Industrial_production            547 non-null    float64
#  4   Labor_Productivity               547 non-null    float64
#  5   PPI                              547 non-null    float64
#  6   Real_disposable_Personal_income  547 non-null    float64
#  7   Real_GDP                         547 non-null    float64
#  8   Unemployment_rate                547 non-null    float64
# dtypes: float64(9)
# memory usage: 42.7 KB
# None
#
# First few rows:
#             Consumer_sentiment  CPI_Urban_consumers  Implicit_price_deflator  \
# DATE
# 1979-01-01                72.1                 68.5                 7.500000
# 1979-02-01                73.9                 69.2                 9.057830
# 1979-03-01                68.4                 69.8                 9.912931
# 1979-04-01                66.0                 70.3                10.200000
# 1979-05-01                68.1                 70.8                10.053736
#
#             Industrial_production  Labor_Productivity   PPI  \
# DATE
# 1979-01-01                51.5250            1.800000  73.8
# 1979-02-01                51.7780            0.567900  74.9
# 1979-03-01                51.9382           -0.110124  75.8
# 1979-04-01                51.3251           -0.400000  76.9
# 1979-05-01                51.7782           -0.467653  77.5
#
#             Real_disposable_Personal_income     Real_GDP  Unemployment_rate
# DATE
# 1979-01-01                           5164.0  7238.727000                5.9
# 1979-02-01                           5184.7  7227.463369                5.9
# 1979-03-01                           5198.5  7231.782451                5.8
# 1979-04-01                           5156.1  7246.454000                5.8
# 1979-05-01                           5132.2  7266.247771                5.6
#
# Last few rows:
#             Consumer_sentiment  CPI_Urban_consumers  Implicit_price_deflator  \
# DATE
# 2024-03-01            79.40000              316.698                 3.396961
# 2024-04-01            77.20000              317.622                 2.300000
# 2024-05-01            69.10000              318.140                -0.095934
# 2024-06-01            68.20000              318.346                -4.142352
# 2024-07-01            90.22176              318.872               -10.190764
#
#             Industrial_production  Labor_Productivity      PPI  \
# DATE
# 2024-03-01             102.406200            2.848912  255.095
# 2024-04-01             102.432900            2.700000  256.984
# 2024-05-01             103.328200            2.438603  255.268
# 2024-06-01             103.994100            2.042040  255.779
# 2024-07-01             103.068095            1.487631  257.723
#
#             Real_disposable_Personal_income      Real_GDP  Unemployment_rate
# DATE
# 2024-03-01                     16924.300000  22842.484189                3.8
# 2024-04-01                     16910.400000  22918.739000                3.9
# 2024-05-01                     16967.200000  23029.105605                4.0
# 2024-06-01                     16984.400000  23181.973491                4.1
# 2024-07-01                     16774.209455  23385.732144                4.3
#
# Missing values in each column:
# Consumer_sentiment                 0
# CPI_Urban_consumers                0
# Implicit_price_deflator            0
# Industrial_production              0
# Labor_Productivity                 0
# PPI                                0
# Real_disposable_Personal_income    0
# Real_GDP                           0
# Unemployment_rate                  0
# dtype: int64
#
# Percentage of missing values in each column:
# Consumer_sentiment                 0.0
# CPI_Urban_consumers                0.0
# Implicit_price_deflator            0.0
# Industrial_production              0.0
# Labor_Productivity                 0.0
# PPI                                0.0
# Real_disposable_Personal_income    0.0
# Real_GDP                           0.0
# Unemployment_rate                  0.0
# dtype: float64
#
# Correlation Matrix:
#                                  Consumer_sentiment  CPI_Urban_consumers  \
# Consumer_sentiment                         1.000000            -0.091603
# CPI_Urban_consumers                       -0.091603             1.000000
# Implicit_price_deflator                   -0.360938            -0.417433
# Industrial_production                      0.048499             0.930278
# Labor_Productivity                         0.323175             0.037389
# PPI                                       -0.267858             0.959294
# Real_disposable_Personal_income           -0.110303             0.985875
# Real_GDP                                  -0.086089             0.992171
# Unemployment_rate                         -0.395806            -0.370520
#
#                                  Implicit_price_deflator  \
# Consumer_sentiment                             -0.360938
# CPI_Urban_consumers                            -0.417433
# Implicit_price_deflator                         1.000000
# Industrial_production                          -0.439473
# Labor_Productivity                             -0.359816
# PPI                                            -0.279944
# Real_disposable_Personal_income                -0.347529
# Real_GDP                                       -0.368059
# Unemployment_rate                               0.064617
#
#                                  Industrial_production  Labor_Productivity  \
# Consumer_sentiment                            0.048499            0.323175
# CPI_Urban_consumers                           0.930278            0.037389
# Implicit_price_deflator                      -0.439473           -0.359816
# Industrial_production                         1.000000            0.066453
# Labor_Productivity                            0.066453            1.000000
# PPI                                           0.859239           -0.119804
# Real_disposable_Personal_income               0.920444            0.044613
# Real_GDP                                      0.946778            0.023348
# Unemployment_rate                            -0.454064            0.148001
#
#                                       PPI  Real_disposable_Personal_income  \
# Consumer_sentiment              -0.267858                        -0.110303
# CPI_Urban_consumers              0.959294                         0.985875
# Implicit_price_deflator         -0.279944                        -0.347529
# Industrial_production            0.859239                         0.920444
# Labor_Productivity              -0.119804                         0.044613
# PPI                              1.000000                         0.951000
# Real_disposable_Personal_income  0.951000                         1.000000
# Real_GDP                         0.955706                         0.993357
# Unemployment_rate               -0.277662                        -0.333453
#
#                                  Real_GDP  Unemployment_rate
# Consumer_sentiment              -0.086089          -0.395806
# CPI_Urban_consumers              0.992171          -0.370520
# Implicit_price_deflator         -0.368059           0.064617
# Industrial_production            0.946778          -0.454064
# Labor_Productivity               0.023348           0.148001
# PPI                              0.955706          -0.277662
# Real_disposable_Personal_income  0.993357          -0.333453
# Real_GDP                         1.000000          -0.388749
# Unemployment_rate               -0.388749           1.000000
#
# Basic statistics of the data:
#        Consumer_sentiment  CPI_Urban_consumers  Implicit_price_deflator  \
# count          547.000000           547.000000               547.000000
# mean            84.990533           185.574307                 2.861424
# std             13.325732            62.096155                 2.225442
# min             50.000000            68.500000               -10.190764
# 25%             74.150000           134.750000                 1.700000
# 50%             89.000000           187.400000                 2.340299
# 75%             94.700000           232.681500                 3.305645
# max            112.000000           318.872000                11.357754
#
#        Industrial_production  Labor_Productivity         PPI  \
# count             547.000000          547.000000  547.000000
# mean               81.341175            1.813637  151.699351
# std                19.233158            1.685946   47.377697
# min                46.871300           -2.400000   73.800000
# 25%                61.724500            0.729903  114.550000
# 50%                89.504600            1.700000  133.300000
# 75%                98.910950            2.709766  193.050000
# max               104.103800            7.275392  280.251000
#
#        Real_disposable_Personal_income      Real_GDP  Unemployment_rate
# count                       547.000000    547.000000         547.000000
# mean                      10422.974423  14197.877043           6.073126
# std                        3625.642884   4647.365823           1.791287
# min                        5118.900000   7163.493068           3.400000
# 25%                        7205.900000  10005.168611           4.700000
# 50%                       10370.700000  14271.694000           5.700000
# 75%                       13023.300000  17691.994363           7.200000
# max                       20422.600000  23385.732144          14.800000
#
# Date range for each column:
# Consumer_sentiment: 1979-01-01 00:00:00 to 2024-07-01 00:00:00
# CPI_Urban_consumers: 1979-01-01 00:00:00 to 2024-07-01 00:00:00
# Implicit_price_deflator: 1979-01-01 00:00:00 to 2024-07-01 00:00:00
# Industrial_production: 1979-01-01 00:00:00 to 2024-07-01 00:00:00
# Labor_Productivity: 1979-01-01 00:00:00 to 2024-07-01 00:00:00
# PPI: 1979-01-01 00:00:00 to 2024-07-01 00:00:00
# Real_disposable_Personal_income: 1979-01-01 00:00:00 to 2024-07-01 00:00:00
# Real_GDP: 1979-01-01 00:00:00 to 2024-07-01 00:00:00
# Unemployment_rate: 1979-01-01 00:00:00 to 2024-07-01 00:00:00

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from statsmodels.tsa.seasonal import seasonal_decompose

# Load the quarterly data (assuming you've already created it)
merged_df_quarterly = merged_df_quarterly_avg

# Function to plot time series and distribution for each column
def plot_column(df, column):
    fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(15, 20))
    
    # Time series plot
    df[column].plot(ax=ax1)
    ax1.set_title(f'{column} - Time Series')
    ax1.set_xlabel('Date')
    ax1.set_ylabel('Value')
    
    # Distribution plot
    sns.histplot(df[column], kde=True, ax=ax2)
    ax2.set_title(f'{column} - Distribution')
    ax2.set_xlabel('Value')
    ax2.set_ylabel('Frequency')
    
    # Seasonal Decomposition
    try:
        result = seasonal_decompose(df[column], model='additive', period=4)  # 4 quarters per year
        result.seasonal.plot(ax=ax3)
        ax3.set_title(f'{column} - Seasonal Component')
        ax3.set_xlabel('Date')
        ax3.set_ylabel('Seasonal Effect')
    except:
        ax3.text(0.5, 0.5, "Seasonal decomposition not possible", ha='center', va='center')
    
    plt.tight_layout()
    plt.savefig(f'{column}_analysis.png')
    plt.close()

# Plot each column
for column in merged_df_quarterly.columns:
    plot_column(merged_df_quarterly, column)

# Print basic statistics
print(merged_df_quarterly.describe())

# Print information about the dataframe
print(merged_df_quarterly.info())

# Check for stationarity
from statsmodels.tsa.stattools import adfuller

def test_stationarity(timeseries):
    result = adfuller(timeseries.dropna())
    print(f'ADF Statistic: {result[0]}')
    print(f'p-value: {result[1]}')
    print('Critical Values:')
    for key, value in result[4].items():
        print(f'\t{key}: {value}')

print("\nStationarity Tests:")
for column in merged_df_quarterly.columns:
    print(f"\n{column}:")
    test_stationarity(merged_df_quarterly[column])
# Out:
#        Consumer_sentiment  CPI_Urban_consumers  Implicit_price_deflator  \
# count          182.000000           183.000000               182.000000
# mean            84.980952           186.059909                 2.906593
# std             13.080161            62.614627                 2.152003
# min             54.366667            69.166667                -1.600000
# 25%             74.775000           135.500000                 1.700000
# 50%             89.533333           187.966667                 2.400000
# 75%             94.200000           232.795000                 3.275000
# max            110.133333           318.872000                11.000000
#
#        Industrial_production  Labor_Productivity         PPI  \
# count             182.000000          182.000000  183.000000
# mean               81.301382            1.815934  152.085594
# std                19.257343            1.701387   47.788383
# min                47.145533           -2.400000   74.833333
# 25%                61.849650            0.725000  115.200000
# 50%                89.428467            1.700000  133.366667
# 75%                98.799167            2.700000  193.583333
# max               103.995800            6.800000  272.937333
#
#        Real_disposable_Personal_income      Real_GDP  Unemployment_rate
# count                       182.000000    182.000000         183.000000
# mean                      10411.342125  14151.784868           6.066667
# std                        3622.960796   4636.795334           1.785305
# min                        5135.733333   7181.743000           3.500000
# 25%                        7203.500000  10006.405500           4.700000
# 50%                       10368.816667  14262.634000           5.700000
# 75%                       13003.008333  17619.263000           7.216667
# max                       18378.266667  22918.739000          13.000000
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 183 entries, 1979-03-31 to 2024-09-30
# Freq: Q-DEC
# Data columns (total 9 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Consumer_sentiment               182 non-null    float64
#  1   CPI_Urban_consumers              183 non-null    float64
#  2   Implicit_price_deflator          182 non-null    float64
#  3   Industrial_production            182 non-null    float64
#  4   Labor_Productivity               182 non-null    float64
#  5   PPI                              183 non-null    float64
#  6   Real_disposable_Personal_income  182 non-null    float64
#  7   Real_GDP                         182 non-null    float64
#  8   Unemployment_rate                183 non-null    float64
# dtypes: float64(9)
# memory usage: 14.3 KB
# None
#
# Stationarity Tests:
#
# Consumer_sentiment:
# ADF Statistic: -2.7551143726721268
# p-value: 0.06497690609629339
# Critical Values:
# 	1%: -3.467004502498507
# 	5%: -2.8776444997243558
# 	10%: -2.575355189707274
#
# CPI_Urban_consumers:
# ADF Statistic: 1.101874181625511
# p-value: 0.9952325862395964
# Critical Values:
# 	1%: -3.4682803641749267
# 	5%: -2.8782017240816327
# 	10%: -2.5756525795918366
#
# Implicit_price_deflator:
# ADF Statistic: -3.2230761202776073
# p-value: 0.018687201368485867
# Critical Values:
# 	1%: -3.469648263987657
# 	5%: -2.878798906308495
# 	10%: -2.5759713094779593
#
# Industrial_production:
# ADF Statistic: -1.0695125908118797
# p-value: 0.7270755773289173
# Critical Values:
# 	1%: -3.4672111510631
# 	5%: -2.877734766803841
# 	10%: -2.575403364197531
#
# Labor_Productivity:
# ADF Statistic: -3.750989230611901
# p-value: 0.0034505033064740277
# Critical Values:
# 	1%: -3.470126426071447
# 	5%: -2.8790075987120027
# 	10%: -2.5760826967621644
#
# PPI:
# ADF Statistic: 1.033931010757994
# p-value: 0.994611366583871
# Critical Values:
# 	1%: -3.4691814633722453
# 	5%: -2.878595143532943
# 	10%: -2.5758625549741803
#
# Real_disposable_Personal_income:
# ADF Statistic: 1.081596600973297
# p-value: 0.995056455820263
# Critical Values:
# 	1%: -3.4685016947910636
# 	5%: -2.8782983668563396
# 	10%: -2.57570415906989
#
# Real_GDP:
# ADF Statistic: 1.187502735527069
# p-value: 0.9958983913141332
# Critical Values:
# 	1%: -3.4672111510631
# 	5%: -2.877734766803841
# 	10%: -2.575403364197531
#
# Unemployment_rate:
# ADF Statistic: -3.110193401789959
# p-value: 0.025807970337540058
# Critical Values:
# 	1%: -3.4668001583460613
# 	5%: -2.8775552336674317
# 	10%: -2.5753075498128246

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
import warnings

# Suppress warnings
warnings.filterwarnings('ignore')

# Load the data
df = merged_df_quarterly_avg

# Function to calculate log difference safely
def safe_log_diff(series):
    return np.log(series).diff()

# Function to calculate percent change
def pct_change(series):
    return series.pct_change()

# Function to apply transformation safely
def safe_transform(series, transform_func):
    transformed = transform_func(series)
    return transformed.replace([np.inf, -np.inf], np.nan).dropna()

# Apply transformations
transformed_df = pd.DataFrame({
    'Consumer_sentiment': safe_transform(df['Consumer_sentiment'], pct_change),
    'CPI_Urban_consumers': safe_transform(df['CPI_Urban_consumers'], safe_log_diff),
    'Implicit_price_deflator': safe_transform(df['Implicit_price_deflator'], safe_log_diff),
    'Industrial_production': safe_transform(df['Industrial_production'], safe_log_diff),
    'Labor_Productivity': safe_transform(df['Labor_Productivity'], pct_change),
    'PPI': safe_transform(df['PPI'], safe_log_diff),
    'Real_disposable_Personal_income': safe_transform(df['Real_disposable_Personal_income'], safe_log_diff),
    'Real_GDP': safe_transform(df['Real_GDP'], safe_log_diff),
    'Unemployment_rate': df['Unemployment_rate'].diff().dropna()
})

# Visualize the transformed series
fig, axes = plt.subplots(3, 3, figsize=(20, 20))
for i, col in enumerate(transformed_df.columns):
    ax = axes[i // 3, i % 3]
    transformed_df[col].plot(ax=ax)
    ax.set_title(col)
    ax.set_xlabel('')
plt.tight_layout()
plt.savefig('transformed_series.png')
plt.close()

# Print summary statistics
print(transformed_df.describe())

# Check for stationarity
def test_stationarity(series):
    series = series.dropna()
    if len(series) == 0:
        print("Not enough data for stationarity test")
        return
    try:
        result = adfuller(series, maxlag=None, regression='ct', autolag='AIC')
        print(f'ADF Statistic: {result[0]}')
        print(f'p-value: {result[1]}')
        print('Critical Values:')
        for key, value in result[4].items():
            print(f'\t{key}: {value}')
    except Exception as e:
        print(f"Error in stationarity test: {str(e)}")

print("\nStationarity Tests:")
for column in transformed_df.columns:
    print(f"\n{column}:")
    test_stationarity(transformed_df[column])

# Save the transformed data
transformed_df.to_csv('transformed_economic_data.csv')

# Print information about any removed data
print("\nNumber of datapoints removed in each series:")
for col in transformed_df.columns:
    original_length = len(df)
    transformed_length = len(transformed_df[col].dropna())
    removed = original_length - transformed_length
    print(f"{col}: {removed} ({removed/original_length:.2%})")
# Out:
#        Consumer_sentiment  CPI_Urban_consumers  Implicit_price_deflator  \
# count          182.000000           182.000000               171.000000
# mean             0.002331             0.008397                -0.022076
# std              0.068379             0.005960                 0.411164
# min             -0.233529            -0.005096                -1.568616
# 25%             -0.032051             0.005112                -0.230236
# 50%              0.000527             0.006498                 0.000000
# 75%              0.033468             0.010445                 0.179106
# max              0.246475             0.036304                 1.568616
#
#        Industrial_production  Labor_Productivity         PPI  \
# count             181.000000          179.000000  182.000000
# mean                0.003817           -0.062890    0.006795
# std                 0.017704            1.994462    0.020652
# min                -0.136088          -20.000000   -0.118677
# 25%                -0.000454           -0.372685   -0.001726
# 50%                 0.005835           -0.063830    0.006555
# 75%                 0.011251            0.416667    0.016275
# max                 0.089128            9.000000    0.075685
#
#        Real_disposable_Personal_income    Real_GDP  Unemployment_rate
# count                       181.000000  181.000000         182.000000
# mean                          0.006548    0.006367          -0.008608
# std                           0.015312    0.010830           0.827085
# min                          -0.080468   -0.082198          -4.200000
# 25%                           0.002703    0.003542          -0.200000
# 50%                           0.006920    0.007005          -0.066667
# 75%                           0.010853    0.010299           0.066667
# max                           0.111125    0.074729           9.166667
#
# Stationarity Tests:
#
# Consumer_sentiment:
# ADF Statistic: -14.584683848591252
# p-value: 3.814193526034158e-22
# Critical Values:
# 	1%: -4.0096774902428285
# 	5%: -3.435029821283931
# 	10%: -3.1414586641558206
#
# CPI_Urban_consumers:
# ADF Statistic: -3.9153956424053433
# p-value: 0.011554272614810958
# Critical Values:
# 	1%: -4.011455293061225
# 	5%: -3.4358815193469385
# 	10%: -3.141957196268222
#
# Implicit_price_deflator:
# ADF Statistic: -18.18104071963237
# p-value: 0.0
# Critical Values:
# 	1%: -4.013034503358437
# 	5%: -3.436637782210462
# 	10%: -3.142399780175046
#
# Industrial_production:
# ADF Statistic: -11.226382993343808
# p-value: 8.393144830943381e-18
# Critical Values:
# 	1%: -4.009965410665295
# 	5%: -3.4351677801783262
# 	10%: -3.1415394238683128
#
# Labor_Productivity:
# ADF Statistic: -12.91930574364757
# p-value: 1.7283035738345633e-20
# Critical Values:
# 	1%: -4.010551134950615
# 	5%: -3.4354484051922847
# 	10%: -3.1417036905168882
#
# PPI:
# ADF Statistic: -4.21172226863387
# p-value: 0.004297850643187409
# Critical Values:
# 	1%: -4.012711131704242
# 	5%: -3.4364829463776627
# 	10%: -3.1423091729829
#
# Real_disposable_Personal_income:
# ADF Statistic: -7.01235810891653
# p-value: 1.3248758306809558e-08
# Critical Values:
# 	1%: -4.011763737803776
# 	5%: -3.4360292512258863
# 	10%: -3.1420436590266103
#
# Real_GDP:
# ADF Statistic: -13.99596364406123
# p-value: 1.1065830101196642e-21
# Critical Values:
# 	1%: -4.009965410665295
# 	5%: -3.4351677801783262
# 	10%: -3.1415394238683128
#
# Unemployment_rate:
# ADF Statistic: -15.00067639949479
# p-value: 2.18452602192135e-22
# Critical Values:
# 	1%: -4.0096774902428285
# 	5%: -3.435029821283931
# 	10%: -3.1414586641558206
#
# Number of datapoints removed in each series:
# Consumer_sentiment: 1 (0.55%)
# CPI_Urban_consumers: 1 (0.55%)
# Implicit_price_deflator: 12 (6.56%)
# Industrial_production: 2 (1.09%)
# Labor_Productivity: 4 (2.19%)
# PPI: 1 (0.55%)
# Real_disposable_Personal_income: 2 (1.09%)
# Real_GDP: 2 (1.09%)
# Unemployment_rate: 1 (0.55%)

# %% [markdown]
# # Interpolation cell:

# %%
#for month interpolation

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
import warnings

# Suppress warnings
warnings.filterwarnings('ignore')

# Load the data
df = merged_df_interpolated

# Function to calculate log difference safely
def safe_log_diff(series):
    return np.log(series).diff()

# Function to calculate percent change
def pct_change(series):
    return series.pct_change()

# Function to apply transformation safely
def safe_transform(series, transform_func):
    transformed = transform_func(series)
    return transformed.replace([np.inf, -np.inf], np.nan).dropna()

# Apply transformations
transformed_df = pd.DataFrame({
    'Consumer_sentiment': safe_transform(df['Consumer_sentiment'], pct_change),
    'CPI_Urban_consumers': safe_transform(df['CPI_Urban_consumers'], safe_log_diff),
    'Implicit_price_deflator': safe_transform(df['Implicit_price_deflator'], safe_log_diff),
    'Industrial_production': safe_transform(df['Industrial_production'], safe_log_diff),
    'Labor_Productivity': safe_transform(df['Labor_Productivity'], pct_change),
    'PPI': safe_transform(df['PPI'], safe_log_diff),
    'Real_disposable_Personal_income': safe_transform(df['Real_disposable_Personal_income'], safe_log_diff),
    'Real_GDP': safe_transform(df['Real_GDP'], safe_log_diff),
    'Unemployment_rate': df['Unemployment_rate'].diff().dropna()
})

# Visualize the transformed series
fig, axes = plt.subplots(3, 3, figsize=(20, 20))
for i, col in enumerate(transformed_df.columns):
    ax = axes[i // 3, i % 3]
    transformed_df[col].plot(ax=ax)
    ax.set_title(col)
    ax.set_xlabel('')
plt.tight_layout()
plt.savefig('transformed_series.png')
plt.close()

# Print summary statistics
print(transformed_df.describe())

# Check for stationarity
def test_stationarity(series):
    series = series.dropna()
    if len(series) == 0:
        print("Not enough data for stationarity test")
        return
    try:
        result = adfuller(series, maxlag=None, regression='ct', autolag='AIC')
        print(f'ADF Statistic: {result[0]}')
        print(f'p-value: {result[1]}')
        print('Critical Values:')
        for key, value in result[4].items():
            print(f'\t{key}: {value}')
    except Exception as e:
        print(f"Error in stationarity test: {str(e)}")

print("\nStationarity Tests:")
for column in transformed_df.columns:
    print(f"\n{column}:")
    test_stationarity(transformed_df[column])

# Save the transformed data
transformed_df.to_csv('interploation_transformed_economic_data.csv')

# Print information about any removed data
print("\nNumber of datapoints removed in each series:")
for col in transformed_df.columns:
    original_length = len(df)
    transformed_length = len(transformed_df[col].dropna())
    removed = original_length - transformed_length
    print(f"{col}: {removed} ({removed/original_length:.2%})")
# Out:
#        Consumer_sentiment  CPI_Urban_consumers  Implicit_price_deflator  \
# count          546.000000           546.000000               525.000000
# mean             0.001835             0.002817                -0.078464
# std              0.053603             0.002274                 1.611685
# min             -0.194164            -0.004774               -36.328742
# 25%             -0.026530             0.001556                -0.075392
# 50%             -0.001313             0.002268                -0.002491
# 75%              0.030485             0.003436                 0.067464
# max              0.322900             0.014094                 3.180750
#
#        Industrial_production  Labor_Productivity         PPI  \
# count             546.000000        5.450000e+02  546.000000
# mean                0.001270       -2.708660e+13    0.002290
# std                 0.009850        4.534733e+14    0.009859
# min                -0.142045       -8.666733e+15   -0.054801
# 25%                -0.002270       -1.386403e-01   -0.001717
# 50%                 0.002029       -2.499644e-03    0.002022
# 75%                 0.005588        1.290823e-01    0.006835
# max                 0.063771        9.700970e+01    0.031620
#
#        Real_disposable_Personal_income    Real_GDP  Unemployment_rate
# count                       546.000000  546.000000         546.000000
# mean                          0.002158    0.002148          -0.002930
# std                           0.015987    0.003828           0.501329
# min                          -0.164977   -0.034059          -2.200000
# 25%                           0.000074    0.001239          -0.100000
# 50%                           0.002270    0.002307           0.000000
# 75%                           0.004366    0.003498           0.100000
# max                           0.206944    0.031605          10.400000
#
# Stationarity Tests:
#
# Consumer_sentiment:
# ADF Statistic: -11.0406843074905
# p-value: 1.863682013626561e-17
# Critical Values:
# 	1%: -3.9756333416844485
# 	5%: -3.418651646179444
# 	10%: -3.1318517504953514
#
# CPI_Urban_consumers:
# ADF Statistic: -5.108567612837669
# p-value: 0.00012990168018040782
# Critical Values:
# 	1%: -3.975920871028089
# 	5%: -3.418790523299655
# 	10%: -3.1319333730441183
#
# Implicit_price_deflator:
# ADF Statistic: -23.121625451958728
# p-value: 0.0
# Critical Values:
# 	1%: -3.97615137499633
# 	5%: -3.4189018502403816
# 	10%: -3.131998801460884
#
# Industrial_production:
# ADF Statistic: -6.091321258667674
# p-value: 1.4092587231401368e-06
# Critical Values:
# 	1%: -3.9757918787911932
# 	5%: -3.4187282210191805
# 	10%: -3.1318967563342675
#
# Labor_Productivity:
# ADF Statistic: -23.41272366830794
# p-value: 0.0
# Critical Values:
# 	1%: -3.975508622568582
# 	5%: -3.418591403709208
# 	10%: -3.1318163431948323
#
# PPI:
# ADF Statistic: -6.228678332195743
# p-value: 7.17350261478013e-07
# Critical Values:
# 	1%: -3.97575993334115
# 	5%: -3.4187127913127404
# 	10%: -3.131887687798408
#
# Real_disposable_Personal_income:
# ADF Statistic: -6.666285290895854
# p-value: 7.919522523771905e-08
# Critical Values:
# 	1%: -3.9760848868984966
# 	5%: -3.4188697389811815
# 	10%: -3.1319799294030872
#
# Real_GDP:
# ADF Statistic: -5.4482946846491105
# p-value: 2.9134601533020998e-05
# Critical Values:
# 	1%: -3.9758884400300065
# 	5%: -3.418774859550687
# 	10%: -3.1319241670942013
#
# Unemployment_rate:
# ADF Statistic: -13.355037351944633
# p-value: 5.0371652532860685e-21
# Critical Values:
# 	1%: -3.9755707506653306
# 	5%: -3.4186214133653787
# 	10%: -3.1318339813302956
#
# Number of datapoints removed in each series:
# Consumer_sentiment: 1 (0.18%)
# CPI_Urban_consumers: 1 (0.18%)
# Implicit_price_deflator: 22 (4.02%)
# Industrial_production: 1 (0.18%)
# Labor_Productivity: 2 (0.37%)
# PPI: 1 (0.18%)
# Real_disposable_Personal_income: 1 (0.18%)
# Real_GDP: 1 (0.18%)
# Unemployment_rate: 1 (0.18%)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the transformed data
transformed_df = pd.read_csv('transformed_economic_data.csv', index_col='DATE', parse_dates=True)

# Compute the correlation matrix
correlation_matrix = transformed_df.corr()

# Create a heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1, center=0)
plt.title('Correlation Heatmap of Transformed Economic Indicators')
plt.tight_layout()
plt.savefig('correlation_heatmap.png')
plt.close()

print("Correlation heatmap has been saved as 'correlation_heatmap.png'")
# Out:
# Correlation heatmap has been saved as 'correlation_heatmap.png'

# %%
merged_df_interpolated
# Out:
#             Consumer_sentiment  CPI_Urban_consumers  Implicit_price_deflator  \
# DATE
# 1979-01-01            72.10000               68.500                 7.500000
# 1979-02-01            73.90000               69.200                 9.057830
# 1979-03-01            68.40000               69.800                 9.912931
# 1979-04-01            66.00000               70.300                10.200000
# 1979-05-01            68.10000               70.800                10.053736
# ...                        ...                  ...                      ...
# 2024-03-01            79.40000              316.698                 3.396961
# 2024-04-01            77.20000              317.622                 2.300000
# 2024-05-01            69.10000              318.140                -0.095934
# 2024-06-01            68.20000              318.346                -4.142352
# 2024-07-01            90.22176              318.872               -10.190764
#
#             Industrial_production  Labor_Productivity      PPI  \
# DATE
# 1979-01-01              51.525000            1.800000   73.800
# 1979-02-01              51.778000            0.567900   74.900
# 1979-03-01              51.938200           -0.110124   75.800
# 1979-04-01              51.325100           -0.400000   76.900
# 1979-05-01              51.778200           -0.467653   77.500
# ...                           ...                 ...      ...
# 2024-03-01             102.406200            2.848912  255.095
# 2024-04-01             102.432900            2.700000  256.984
# 2024-05-01             103.328200            2.438603  255.268
# 2024-06-01             103.994100            2.042040  255.779
# 2024-07-01             103.068095            1.487631  257.723
#
#             Real_disposable_Personal_income      Real_GDP  Unemployment_rate
# DATE
# 1979-01-01                      5164.000000   7238.727000                5.9
# 1979-02-01                      5184.700000   7227.463369                5.9
# 1979-03-01                      5198.500000   7231.782451                5.8
# 1979-04-01                      5156.100000   7246.454000                5.8
# 1979-05-01                      5132.200000   7266.247771                5.6
# ...                                     ...           ...                ...
# 2024-03-01                     16924.300000  22842.484189                3.8
# 2024-04-01                     16910.400000  22918.739000                3.9
# 2024-05-01                     16967.200000  23029.105605                4.0
# 2024-06-01                     16984.400000  23181.973491                4.1
# 2024-07-01                     16774.209455  23385.732144                4.3
#
# [547 rows x 9 columns]
